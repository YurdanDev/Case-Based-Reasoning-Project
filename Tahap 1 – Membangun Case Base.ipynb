# %%
# !pip install pandas requests beautifulsoup4 pdfminer.six lxml > /dev/null 2>&1
# Out:
# The system cannot find the path specified.

# %%
import argparse
import io
import os
import re
import time
import urllib
from concurrent.futures import ThreadPoolExecutor, wait
from datetime import date
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pdfminer import high_level

# %%
def create_path(folder_name):
    path = os.path.join(os.getcwd(), folder_name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

# %%
def open_page(link):
    count = 0
    while count < 3:
        try:
            return BeautifulSoup(requests.get(link).text, "lxml")
        except:
            count += 1
            time.sleep(5)

def get_detail(soup, keyword):
    try:
        text = (
            soup.find(lambda tag: tag.name == "td" and keyword in tag.text)
            .find_next()
            .get_text()
            .strip()
        )
        return text
    except:
        return ""

def get_pdf(url, path_pdf):
    file = urllib.request.urlopen(url)
    file_name = file.info().get_filename().replace("/", " ")
    file_content = file.read()
    with open(f"{path_pdf}/{file_name}", "wb") as out_file:
        out_file.write(file_content)
    return io.BytesIO(file_content), file_name

# %%
def clean_text(text):
    text = text.replace("M a h ka m a h A g u n g R e p u blik In d o n esia\n", "")
    text = text.replace("Disclaimer\n", "")
    text = text.replace(
        "Kepaniteraan Mahkamah Agung Republik Indonesia berusaha untuk selalu mencantumkan informasi paling kini dan akurat sebagai bentuk komitmen Mahkamah Agung untuk pelayanan publik, transparansi dan akuntabilitas\n",
        "",
    )
    text = text.replace(
        "pelaksanaan fungsi peradilan. Namun dalam hal-hal tertentu masih dimungkinkan terjadi permasalahan teknis terkait dengan akurasi dan keterkinian informasi yang kami sajikan, hal mana akan terus kami perbaiki dari waktu kewaktu.\n",
        "",
    )
    text = text.replace(
        "Dalam hal Anda menemukan inakurasi informasi yang termuat pada situs ini atau informasi yang seharusnya ada, namun belum tersedia, maka harap segera hubungi Kepaniteraan Mahkamah Agung RI melalui :\n",
        "",
    )
    text = text.replace(
        "Email : kepaniteraan@mahkamahagung.go.id    Telp : 021-384 3348 (ext.318)\n",
        "",
    )
    return text

# %%
def is_url_already_scraped(url, destination):
    """
    Checks if a URL has already been scraped and saved in the CSV file.

    Args:
        url (str): The URL to check.
        destination (str): The path to the output CSV file.

    Returns:
        bool: True if the URL exists in the CSV, False otherwise.
    """
    if not os.path.isfile(f"{destination}.csv"):
      return False

    try:
        df = pd.read_csv(f"{destination}.csv")
        return url in df["link"].values
    except pd.errors.EmptyDataError:
      return False

# %%
def extract_data(link, keyword_url):
    global today
    global path_output
    global path_pdf
    global download_pdf

    path_output = 'data/raw/CSV'
    path_pdf = 'data/raw/PDF'
    today = date.today().strftime("%Y-%m-%d")

    keyword_url = keyword_url.replace("/", " ")
    if keyword_url.startswith("https"):
        keyword_url = ""
    destination = f"{path_output}/putusan_ma_{keyword_url}_{today}"

    if is_url_already_scraped(link, destination):
        print(f"Skipping duplicate URL: {link}")
        return

    soup = open_page(link)
    table = soup.find("table", {"class": "table"})
    judul = table.find("h2").text
    table.find("h2").decompose()

    nomor = get_detail(table, "Nomor")
    tingkat_proses = get_detail(table, "Tingkat Proses")
    klasifikasi = get_detail(table, "Klasifikasi")
    kata_kunci = get_detail(table, "Kata Kunci")
    tahun = get_detail(table, "Tahun")
    tanggal_register = get_detail(table, "Tanggal Register")
    lembaga_peradilan = get_detail(table, "Lembaga Peradilan")
    jenis_lembaga_peradilan = get_detail(table, "Jenis Lembaga Peradilan")
    hakim_ketua = get_detail(table, "Hakim Ketua")
    hakim_anggota = get_detail(table, "Hakim Anggota")
    panitera = get_detail(table, "Panitera")
    amar = get_detail(table, "Amar")
    amar_lainnya = get_detail(table, "Amar Lainnya")
    catatan_amar = get_detail(table, "Catatan Amar")
    tanggal_musyawarah = get_detail(table, "Tanggal Musyawarah")
    tanggal_dibacakan = get_detail(table, "Tanggal Dibacakan")
    kaidah = get_detail(table, "Kaidah")
    abstrak = get_detail(table, "Abstrak")

    try:
        link_pdf = soup.find("a", href=re.compile(r"/pdf/"))["href"]
        file_pdf, file_name_pdf = get_pdf(link_pdf, path_pdf)
        text_pdf = high_level.extract_text(file_pdf)
        text_pdf = clean_text(text_pdf)
    except:
        link_pdf = ""
        text_pdf = ""
        file_name_pdf = ""

    data = [
        judul,
        nomor,
        tingkat_proses,
        klasifikasi,
        kata_kunci,
        tahun,
        tanggal_register,
        lembaga_peradilan,
        jenis_lembaga_peradilan,
        hakim_ketua,
        hakim_anggota,
        panitera,
        amar,
        amar_lainnya,
        catatan_amar,
        tanggal_musyawarah,
        tanggal_dibacakan,
        kaidah,
        abstrak,
        link,
        link_pdf,
        file_name_pdf,
        text_pdf,
    ]
    result = pd.DataFrame(
        [data],
        columns=[
            "judul",
            "nomor",
            "tingkat_proses",
            "klasifikasi",
            "kata_kunci",
            "tahun",
            "tanggal_register",
            "lembaga_peradilan",
            "jenis_lembaga_peradilan",
            "hakim_ketua",
            "hakim_anggota",
            "panitera",
            "amar",
            "amar_lainnya",
            "catatan_amar",
            "tanggal_musyawarah",
            "tanggal_dibacakan",
            "kaidah",
            "abstrak",
            "link",
            "link_pdf",
            "file_name_pdf",
            "text_pdf",
        ],
    )

    print(destination)
    if not os.path.isfile(f"{destination}.csv"):
        result.to_csv(f"{destination}.csv", header=True, index=False)
    else:
        result.to_csv(f"{destination}.csv", mode="a", header=False, index=False)

# %%
def run_scraper(keyword=None, url=None, sort_date=True, download_pdf=True):
    if not keyword and not url:
        print("Please provide a keyword or URL")
        return

    path_output = 'data/raw/CSV'
    path_pdf = 'data/raw/PDF'

    today = date.today().strftime("%Y-%m-%d")

    link = f"https://putusan3.mahkamahagung.go.id/search.html?q={keyword}&page=1"

    if url:
        link = url

    soup = open_page(link)

    last_page = int(
        soup.find_all("a", {"class": "page-link"})[-1].get("data-ci-pagination-page")
    )

    if url:
        print(f"Scraping with url: {url} - {20 * last_page} data - {last_page} page")
    else:
        print(f"Scraping with keyword: {keyword} - {20 * last_page} data - {last_page} page")

    if url:
        keyword_url = url
    else:
        keyword_url = keyword

    futures = []
    with ThreadPoolExecutor(max_workers=4) as executor:
        for page in range(last_page):
            futures.append(
                executor.submit(run_process, keyword_url, page + 1, sort_date)
            )
    wait(futures)

def run_process(keyword_url, page, sort_page):
    if keyword_url.startswith("https"):
        link = f"{keyword_url}&page={page}"
    else:
        link = f"https://putusan3.mahkamahagung.go.id/search.html?q={keyword_url}&page={page}"
    if sort_page:
        link = f"{link}&obf=TANGGAL_PUTUS&obm=desc"

    print(link)

    soup = open_page(link)
    links = soup.find_all("a", {"href": re.compile("/direktori/putusan")})

    for link in links:
        extract_data(link["href"], keyword_url)

def scrape_specific_url(url, download_pdf=True):
    if not url or not url.startswith("https://"):
        print("Please provide a valid URL")
        return

    path_output = 'data/raw/CSV'
    path_pdf = 'data/raw/PDF'
    today = date.today().strftime("%Y-%m-%d")

    extract_data(url, url, path_output, path_pdf, today)

# %%
# Penganiayaan PN MEDAN
run_scraper(url="https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=4210395c07581866de499a7b125ea4bc&jd=&tp=0&court=098629PN185&t_put=2024&t_reg=&t_upl=&t_pr=")
# Out:
# Scraping with url: https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=4210395c07581866de499a7b125ea4bc&jd=&tp=0&court=098629PN185&t_put=2024&t_reg=&t_upl=&t_pr= - 100 data - 5 page
# https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=4210395c07581866de499a7b125ea4bc&jd=&tp=0&court=098629PN185&t_put=2024&t_reg=&t_upl=&t_pr=&page=1&obf=TANGGAL_PUTUS&obm=desc
# https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=4210395c07581866de499a7b125ea4bc&jd=&tp=0&court=098629PN185&t_put=2024&t_reg=&t_upl=&t_pr=&page=2&obf=TANGGAL_PUTUS&obm=desc
# https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=4210395c07581866de499a7b125ea4bc&jd=&tp=0&court=098629PN185&t_put=2024&t_reg=&t_upl=&t_pr=&page=3&obf=TANGGAL_PUTUS&obm=desc
# https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=4210395c07581866de499a7b125ea4bc&jd=&tp=0&court=098629PN185&t_put=2024&t_reg=&t_upl=&t_pr=&page=4&obf=TANGGAL_PUTUS&obm=desc
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# Skipping duplicate URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaf051afe3f471a4876a313733333533.html
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# Skipping duplicate URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaf051afe4a8e6ac9996313733333534.html
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=4210395c07581866de499a7b125ea4bc&jd=&tp=0&court=098629PN185&t_put=2024&t_reg=&t_upl=&t_pr=&page=5&obf=TANGGAL_PUTUS&obm=desc
# Skipping duplicate URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaf051afe4a8e6ac9996313733333534.html
# Skipping duplicate URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaf051afe397d2fa876a313733333532.html
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25
# data/raw/CSV/putusan_ma__2025-06-25

# %%
import os
import re
from pdfminer.high_level import extract_text
from datetime import datetime

# %%
# === Konfigurasi Path ===
PDF_DIR = 'data/raw/PDF'
TEXT_DIR = 'data/raw'
LOG_PATH = 'logs/cleaning.log'

# === Buat Folder jika Belum Ada ===
os.makedirs(TEXT_DIR, exist_ok=True)
os.makedirs(os.path.dirname(LOG_PATH), exist_ok=True)

# %%
# === Fungsi Pembersihan Teks ===
def clean_text(text):
    # Hapus watermark dan disclaimer tetap dari Mahkamah Agung
    text = text.replace("M a h ka m a h A g u n g R e p u blik In d o n esia\n", "")
    text = text.replace("Disclaimer\n", "")
    text = text.replace(
        "Kepaniteraan Mahkamah Agung Republik Indonesia berusaha untuk selalu mencantumkan informasi paling kini dan akurat sebagai bentuk komitmen Mahkamah Agung untuk pelayanan publik, transparansi dan akuntabilitas\n",
        ""
    )
    text = text.replace(
        "pelaksanaan fungsi peradilan. Namun dalam hal-hal tertentu masih dimungkinkan terjadi permasalahan teknis terkait dengan akurasi dan keterkinian informasi yang kami sajikan, hal mana akan terus kami perbaiki dari waktu kewaktu.\n",
        ""
    )
    text = text.replace(
        "Dalam hal Anda menemukan inakurasi informasi yang termuat pada situs ini atau informasi yang seharusnya ada, namun belum tersedia, maka harap segera hubungi Kepaniteraan Mahkamah Agung RI melalui :\n",
        ""
    )
    text = text.replace(
        "Email : kepaniteraan@mahkamahagung.go.id    Telp : 021-384 3348 (ext.318)\n",
        ""
    )

    # Hapus baris kosong berlebih, nomor halaman, dsb
    text = re.sub(r'\n\s*\n', '\n', text)
    text = re.sub(r'Halaman\s+\d+\s+dari\s+\d+', '', text, flags=re.I)

    # Normalisasi teks
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)  # hapus tanda baca (opsional)
    text = re.sub(r'\s+', ' ', text)     # normalisasi spasi

    return text.strip()

# %%
# === Fungsi Validasi Keutuhan Teks ===
def is_valid_text(text, min_words=500):
    return len(text.split()) >= min_words  # asumsikan ≥ 500 kata cukup utuh (~80%)

# %%
# === Proses Seluruh PDF ===
def convert_and_clean_all():
    log_lines = []
    for i, filename in enumerate(sorted(os.listdir(PDF_DIR))):
        if filename.lower().endswith('.pdf'):
            pdf_path = os.path.join(PDF_DIR, filename)
            case_id = f"case_{i+1:03d}"
            txt_path = os.path.join(TEXT_DIR, f"{case_id}.txt")

            try:
                # Ekstraksi teks
                raw_text = extract_text(pdf_path)
                cleaned_text = clean_text(raw_text)
                valid = is_valid_text(cleaned_text)

                # Simpan hasil pembersihan
                with open(txt_path, 'w', encoding='utf-8') as f:
                    f.write(cleaned_text)

                # Log hasil
                log_line = f"[{datetime.now()}] {filename} → {case_id}.txt | Status: {'OK' if valid else 'INCOMPLETE'} | Words: {len(cleaned_text.split())}"
                print(log_line)
                log_lines.append(log_line)

            except Exception as e:
                error_line = f"[{datetime.now()}] {filename} → ERROR: {str(e)}"
                print(error_line)
                log_lines.append(error_line)

    # Simpan log
    with open(LOG_PATH, 'w', encoding='utf-8') as log_file:
        log_file.write("\n".join(log_lines))


# === Jalankan Proses ===
convert_and_clean_all()
# Out:
# [2025-06-25 18:30:33.320097] putusan_1006_pid.b_2024_pn_mdn_20250625174208.pdf → case_001.txt | Status: OK | Words: 3978
# [2025-06-25 18:30:34.097868] putusan_100_pid.b_2024_pn_mdn_20250625174338.pdf → case_002.txt | Status: OK | Words: 4937
# [2025-06-25 18:30:34.931940] putusan_101_pid.b_2024_pn_mdn_20250625174255.pdf → case_003.txt | Status: OK | Words: 5354
# [2025-06-25 18:30:36.051612] putusan_1055_pid.b_2024_pn_mdn_20250625173949.pdf → case_004.txt | Status: OK | Words: 7577
# [2025-06-25 18:30:36.816608] putusan_1063_pid.b_2024_pn_mdn_20250625174344.pdf → case_005.txt | Status: OK | Words: 5246
# [2025-06-25 18:30:37.672147] putusan_1080_pid.b_2024_pn_mdn_20250625174440.pdf → case_006.txt | Status: OK | Words: 5566
# [2025-06-25 18:30:38.202551] putusan_1101_pid.b_2024_pn_mdn_20250625174256.pdf → case_007.txt | Status: OK | Words: 3330
# [2025-06-25 18:30:38.634406] putusan_1102_pid.b_2024_pn_mdn_20250625174621.pdf → case_008.txt | Status: OK | Words: 2827
# [2025-06-25 18:30:39.438560] putusan_1114_pid.b_2024_pn_mdn_20250625173902.pdf → case_009.txt | Status: OK | Words: 5812
# [2025-06-25 18:30:40.266617] putusan_1115_pid.b_2024_pn_mdn_20250625173724.pdf → case_010.txt | Status: OK | Words: 5938
# [2025-06-25 18:30:41.100671] putusan_1116_pid.b_2024_pn_mdn_20250625173642.pdf → case_011.txt | Status: OK | Words: 5829
# [2025-06-25 18:30:41.552389] putusan_1124_pid.b_2024_pn_mdn_20250625174833.pdf → case_012.txt | Status: OK | Words: 3074
# [2025-06-25 18:30:43.863789] putusan_1145_pid.b_2024_pn_mdn_20250625174515.pdf → case_013.txt | Status: OK | Words: 15945
# [2025-06-25 18:30:45.989531] putusan_1157_pid.b_2024_pn_mdn_20250625173554.pdf → case_014.txt | Status: OK | Words: 15143
# [2025-06-25 18:30:46.574090] putusan_119_pdt.g_2025_pa.rmb_20250625175810.pdf → case_015.txt | Status: OK | Words: 3639
# [2025-06-25 18:30:47.611082] putusan_1227_pid.b_2024_pn_mdn_20250625173813.pdf → case_016.txt | Status: OK | Words: 5915
# [2025-06-25 18:30:48.220741] putusan_1263_pid.b_2024_pn_mdn_20250625174822.pdf → case_017.txt | Status: OK | Words: 3834
# [2025-06-25 18:30:48.899779] putusan_1276_pid.b_2024_pn_mdn_20250625174031.pdf → case_018.txt | Status: OK | Words: 4465
# [2025-06-25 18:30:49.414961] putusan_1282_pid.b_2024_pn_mdn_20250625174120.pdf → case_019.txt | Status: OK | Words: 3418
# [2025-06-25 18:30:50.758686] putusan_1295_pid.b_2024_pn_mdn_20250625174433.pdf → case_020.txt | Status: OK | Words: 9642
# [2025-06-25 18:30:51.227698] putusan_132_pid.b_2024_pn_mdn_20250625175255.pdf → case_021.txt | Status: OK | Words: 2880
# [2025-06-25 18:30:51.819487] putusan_1333_pid.b_2024_pn_mdn_20250625174918.pdf → case_022.txt | Status: OK | Words: 3535
# [2025-06-25 18:30:52.386818] putusan_1355_pid.b_2024_pn_mdn_20250625174733.pdf → case_023.txt | Status: OK | Words: 3526
# [2025-06-25 18:30:53.031822] putusan_1454_pid.b_2024_pn_mdn_20250625175017.pdf → case_024.txt | Status: OK | Words: 3963
# [2025-06-25 18:30:53.638507] putusan_1455_pid.b_2024_pn_mdn_20250625175058.pdf → case_025.txt | Status: OK | Words: 3966
# [2025-06-25 18:30:54.149347] putusan_1499_pid.b_2024_pn_mdn_20250625174604.pdf → case_026.txt | Status: OK | Words: 3251
# [2025-06-25 18:30:54.836882] putusan_1522_pid.b_2024_pn_mdn_20250625174131.pdf → case_027.txt | Status: OK | Words: 4495
# [2025-06-25 18:30:55.347342] putusan_1535_pid.b_2024_pn_mdn_20250625174350.pdf → case_028.txt | Status: OK | Words: 3086
# [2025-06-25 18:30:55.826732] putusan_1551_pid.b_2024_pn_mdn_20250625174302.pdf → case_029.txt | Status: OK | Words: 2656
# [2025-06-25 18:30:56.556580] putusan_1606_pid.b_2024_pn_mdn_20250625174652.pdf → case_030.txt | Status: OK | Words: 4687
# [2025-06-25 18:30:57.049746] putusan_1693_pid.b_2024_pn_mdn_20250625173819.pdf → case_031.txt | Status: OK | Words: 3193
# [2025-06-25 18:30:57.806432] putusan_1710_pid.b_2024_pn_mdn_20250625173955.pdf → case_032.txt | Status: OK | Words: 4673
# [2025-06-25 18:30:58.292531] putusan_1730_pid.b_2024_pn_mdn_20250625173730.pdf → case_033.txt | Status: OK | Words: 3032
# [2025-06-25 18:30:59.003328] putusan_1782_pid.b_2024_pn_mdn_20250625174043.pdf → case_034.txt | Status: OK | Words: 4490
# [2025-06-25 18:30:59.476579] putusan_1846_pid.b_2024_pn_mdn_20250625174214.pdf → case_035.txt | Status: OK | Words: 2953
# [2025-06-25 18:31:00.114231] putusan_1904_pid.b_2024_pn_mdn_20250625173655.pdf → case_036.txt | Status: OK | Words: 4150
# [2025-06-25 18:31:00.616085] putusan_1959_pid.b_2024_pn_mdn_20250625173908.pdf → case_037.txt | Status: OK | Words: 2732
# [2025-06-25 18:31:01.124284] putusan_2065_pid.b_2024_pn_mdn_20250625173613.pdf → case_038.txt | Status: OK | Words: 2907
# [2025-06-25 18:31:02.152997] putusan_2153_pid.b_2023_pn_mdn_20250625175553.pdf → case_039.txt | Status: OK | Words: 6066
# [2025-06-25 18:31:02.777458] putusan_2163_pid.b_2023_pn_mdn_20250625175717.pdf → case_040.txt | Status: OK | Words: 4007
# [2025-06-25 18:31:03.300119] putusan_2173_pid.b_2023_pn_mdn_20250625175730.pdf → case_041.txt | Status: OK | Words: 3328
# [2025-06-25 18:31:03.936801] putusan_219_pid.b_2024_pn_mdn_20250625175309.pdf → case_042.txt | Status: OK | Words: 4239
# [2025-06-25 18:31:04.491660] putusan_222_pid.b_2024_pn_mdn_20250625174557.pdf → case_043.txt | Status: OK | Words: 3493
# [2025-06-25 18:31:05.022399] putusan_222_pid.b_2024_pn_mdn_20250625174639.pdf → case_044.txt | Status: OK | Words: 3493
# [2025-06-25 18:31:05.694629] putusan_2316_pid.b_2023_pn_mdn_20250625175459.pdf → case_045.txt | Status: OK | Words: 3925
# [2025-06-25 18:31:06.408434] putusan_2333_pid.b_2023_pn_mdn_20250625175525.pdf → case_046.txt | Status: OK | Words: 4396
# [2025-06-25 18:31:06.965500] putusan_2334_pid.b_2023_pn_mdn_20250625175643.pdf → case_047.txt | Status: OK | Words: 3684
# [2025-06-25 18:31:07.857279] putusan_2343_pid.b_2023_pn_mdn_20250625175747.pdf → case_048.txt | Status: OK | Words: 5862
# [2025-06-25 18:31:08.756227] putusan_2350_pid.b_2023_pn_mdn_20250625175612.pdf → case_049.txt | Status: OK | Words: 6047
# [2025-06-25 18:31:09.438929] putusan_2402_pid.b_2023_pn_mdn_20250625175346.pdf → case_050.txt | Status: OK | Words: 4528
# [2025-06-25 18:31:10.169530] putusan_2456_pid.b_2023_pn_mdn_20250625175412.pdf → case_051.txt | Status: OK | Words: 5421
# [2025-06-25 18:31:10.915482] putusan_2496_pid.b_2023_pn_mdn_20250625175424.pdf → case_052.txt | Status: OK | Words: 4695
# [2025-06-25 18:31:11.732234] putusan_2512_pid.b_2023_pn_mdn_20250625175400.pdf → case_053.txt | Status: OK | Words: 4533
# [2025-06-25 18:31:12.946627] putusan_2522_pid.b_2023_pn_mdn_20250625175334.pdf → case_054.txt | Status: OK | Words: 4443
# [2025-06-25 18:31:13.873045] putusan_255_pid.b_2024_pn_mdn_20250625173712.pdf → case_055.txt | Status: OK | Words: 6059
# [2025-06-25 18:31:14.460006] putusan_2587_pid.b_2023_pn_mdn_20250625174953.pdf → case_056.txt | Status: OK | Words: 3680
# [2025-06-25 18:31:14.836667] putusan_2595_pid.b_2023_pn_mdn_20250625175448.pdf → case_057.txt | Status: OK | Words: 2586
# [2025-06-25 18:31:15.256312] putusan_2652_pid.b_2023_pn_mdn_20250625175321.pdf → case_058.txt | Status: OK | Words: 2812
# [2025-06-25 18:31:15.805610] putusan_275_pid.b_2024_pn_mdn_20250625174721.pdf → case_059.txt | Status: OK | Words: 3532
# [2025-06-25 18:31:16.771474] putusan_30_pid.b_2024_pn_mdn_20250625175243.pdf → case_060.txt | Status: OK | Words: 6646
# [2025-06-25 18:31:17.545408] putusan_336_pid.b_2024_pn_mdn_20250625174113.pdf → case_061.txt | Status: OK | Words: 5117
# [2025-06-25 18:31:18.905611] putusan_337_pid.b_2024_pn_mdn_20250625175010.pdf → case_062.txt | Status: OK | Words: 9583
# [2025-06-25 18:31:20.264945] putusan_338_pid.b_2024_pn_mdn_20250625173625.pdf → case_063.txt | Status: OK | Words: 9561
# [2025-06-25 18:31:20.797126] putusan_367_pid.b_2024_pn_mdn_20250625174205.pdf → case_064.txt | Status: OK | Words: 3295
# [2025-06-25 18:31:21.479501] putusan_37_pid.b_2024_pn_mdn_20250625175227.pdf → case_065.txt | Status: OK | Words: 4451
# [2025-06-25 18:31:21.949452] putusan_383_pid.b_2024_pn_mdn_20250625173850.pdf → case_066.txt | Status: OK | Words: 3123
# [2025-06-25 18:31:22.472129] putusan_392_pid.b_2024_pn_mdn_20250625174841.pdf → case_067.txt | Status: OK | Words: 3113
# [2025-06-25 18:31:25.387652] putusan_41_pid.b_2025_pn_rta_20250625175104.pdf → case_068.txt | Status: OK | Words: 22152
# [2025-06-25 18:31:28.633514] putusan_41_pid.b_2025_pn_rta_20250625175140.pdf → case_069.txt | Status: OK | Words: 22152
# [2025-06-25 18:31:31.578870] putusan_41_pid.b_2025_pn_rta_20250625175148.pdf → case_070.txt | Status: OK | Words: 22152
# [2025-06-25 18:31:32.710222] putusan_446_pid.b_2024_pn_mdn_20250625174333.pdf → case_071.txt | Status: OK | Words: 7010
# [2025-06-25 18:31:33.836608] putusan_447_pid.b_2024_pn_mdn_20250625174527.pdf → case_072.txt | Status: OK | Words: 7264
# [2025-06-25 18:31:34.151743] putusan_46_pid.b_2024_pn_mdn_20250625175028.pdf → case_073.txt | Status: OK | Words: 2058
# [2025-06-25 18:31:34.817998] putusan_509_pid.b_2024_pn_mdn_20250625174928.pdf → case_074.txt | Status: OK | Words: 4322
# [2025-06-25 18:31:35.271842] putusan_530_pid.b_2024_pn_mdn_20250625173800.pdf → case_075.txt | Status: OK | Words: 2993
# [2025-06-25 18:31:35.842882] putusan_532_pid.b_2024_pn_mdn_20250625174704.pdf → case_076.txt | Status: OK | Words: 3626
# [2025-06-25 18:31:36.476913] putusan_534_pid.b_2024_pn_mdn_20250625174157.pdf → case_077.txt | Status: OK | Words: 3961
# [2025-06-25 18:31:37.230273] putusan_539_pid.b_2024_pn_mdn_20250625174609.pdf → case_078.txt | Status: OK | Words: 5360
# [2025-06-25 18:31:37.829843] putusan_542_pid.b_2024_pn_mdn_20250625174753.pdf → case_079.txt | Status: OK | Words: 4039
# [2025-06-25 18:31:38.472957] putusan_558_pid.b_2024_pn_mdn_20250625174247.pdf → case_080.txt | Status: OK | Words: 4466
# [2025-06-25 18:31:39.024540] putusan_56_pid.b_2024_pn_mdn_20250625174809.pdf → case_081.txt | Status: OK | Words: 3379
# [2025-06-25 18:31:39.841179] putusan_570_pid.b_2024_pn_mdn_20250625173831.pdf → case_082.txt | Status: OK | Words: 5899
# [2025-06-25 18:31:40.364271] putusan_586_pid.b_2024_pn_mdn_20250625174013.pdf → case_083.txt | Status: OK | Words: 2994
# [2025-06-25 18:31:40.818417] putusan_587_pid.b_2024_pn_mdn_20250625174428.pdf → case_084.txt | Status: OK | Words: 3076
# [2025-06-25 18:31:42.031412] putusan_58_pid.b_2024_pn_mdn_20250625174025.pdf → case_085.txt | Status: OK | Words: 7799
# [2025-06-25 18:31:43.446283] putusan_599_pid.b_2024_pn_mdn_20250625173919.pdf → case_086.txt | Status: OK | Words: 6249
# [2025-06-25 18:31:44.453799] putusan_59_pid.b_2024_pn_mdn_20250625173937.pdf → case_087.txt | Status: OK | Words: 6786
# [2025-06-25 18:31:45.053511] putusan_60_pid.b_2024_pn_mdn_20250625175110.pdf → case_088.txt | Status: OK | Words: 3489
# [2025-06-25 18:31:45.639919] putusan_612_pid.b_2024_pn_mdn_20250625174101.pdf → case_089.txt | Status: OK | Words: 3475
# [2025-06-25 18:31:46.173571] putusan_621_pid.b_2024_pn_mdn_20250625173548.pdf → case_090.txt | Status: OK | Words: 3373
# [2025-06-25 18:31:46.640077] putusan_76_pid.b_2024_pn_mdn_20250625174858.pdf → case_091.txt | Status: OK | Words: 3038
# [2025-06-25 18:31:47.309049] putusan_773_pid.b_2024_pn_mdn_20250625175054.pdf → case_092.txt | Status: OK | Words: 4033
# [2025-06-25 18:31:48.242590] putusan_820_pid.b_2024_pn_mdn_20250625174912.pdf → case_093.txt | Status: OK | Words: 6335
# [2025-06-25 18:31:48.850541] putusan_87_pid.b_2024_pn_mdn_20250625174512.pdf → case_094.txt | Status: OK | Words: 3732
# [2025-06-25 18:31:49.695814] putusan_880_pid.b_2024_pn_mdn_20250625174521.pdf → case_095.txt | Status: OK | Words: 6405
# [2025-06-25 18:31:50.223839] putusan_932_pid.b_2024_pn_mdn_20250625174739.pdf → case_096.txt | Status: OK | Words: 3155
# [2025-06-25 18:31:50.731942] putusan_979_pid.b_2024_pn_mdn_20250625175005.pdf → case_097.txt | Status: OK | Words: 3196
# [2025-06-25 18:31:51.524707] putusan_99_pid.b_2024_pn_mdn_20250625174420.pdf → case_098.txt | Status: OK | Words: 5053

# %%
import pandas as pd

# %%
# Load CSV dari local folder
file_path = 'data/raw/CSV/putusan_ma__2025-06-25.csv'
df = pd.read_csv(file_path)

# Tampilkan data awal
df.head()
# Out:
#                                                judul                   nomor  \
# 0  Putusan PN MEDAN Nomor 621/Pid.B/2024/PN Mdn T...   621/Pid.B/2024/PN Mdn
# 1  Putusan PN MEDAN Nomor 1157/Pid.B/2024/PN Mdn ...  1157/Pid.B/2024/PN Mdn
# 2  Putusan PN MEDAN Nomor 2065/Pid.B/2024/PN Mdn ...  2065/Pid.B/2024/PN Mdn
# 3  Putusan PN MEDAN Nomor 826/Pid.B/2024/PN Mdn T...   826/Pid.B/2024/PN Mdn
# 4  Putusan PN MEDAN Nomor 338/Pid.B/2024/PN Mdn T...   338/Pid.B/2024/PN Mdn
#
#   tingkat_proses                               klasifikasi    kata_kunci  \
# 0        Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 1        Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 2        Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 3        Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 4        Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
#
#    tahun  tanggal_register lembaga_peradilan jenis_lembaga_peradilan  \
# 0   2024        2 Mei 2024          PN MEDAN                      PN
# 1   2024      22 Juli 2024          PN MEDAN                      PN
# 2   2024  12 Nopember 2024          PN MEDAN                      PN
# 3   2024       3 Juni 2024          PN MEDAN                      PN
# 4   2024      4 Maret 2024          PN MEDAN                      PN
#
#                           hakim_ketua  ...                   amar_lainnya  \
# 0      Hakim Ketua Lucas Sahabat Duha  ...  PIDANA PENJARA WAKTU TERTENTU
# 1       Hakim Ketua Donald Panggabean  ...  PIDANA PENJARA WAKTU TERTENTU
# 2          Hakim Ketua Muhammad Kasim  ...  PIDANA PENJARA WAKTU TERTENTU
# 3  Hakim Ketua Frans Effendi Manurung  ...  PIDANA PENJARA WAKTU TERTENTU
# 4            Hakim Ketua Khairulludin  ...  PIDANA PENJARA WAKTU TERTENTU
#
#                                         catatan_amar tanggal_musyawarah  \
# 0  M E N G A D I L I Menyatakan Terdakwa I. M. Ka...       23 Juli 2024
# 1  MENGADILI:  Menyatakan Terdakwa Erwin tersebut...     2 Oktober 2024
# 2  MENGADILI: Menyatakan Terdakwa Joshua Corneliu...   19 Desember 2024
# 3  M E N G A D I L I : 1. Menyatakan Terdakwa I G...       18 Juli 2024
# 4  M E N G A D I L I Menyatakan terdakwa M. SYAFR...        13 Mei 2024
#
#   tanggal_dibacakan kaidah abstrak  \
# 0      23 Juli 2024      —     NaN
# 1    2 Oktober 2024      —     NaN
# 2  19 Desember 2024      —     NaN
# 3      18 Juli 2024      —     NaN
# 4       13 Mei 2024      —     NaN
#
#                                                 link  \
# 0  https://putusan3.mahkamahagung.go.id/direktori...
# 1  https://putusan3.mahkamahagung.go.id/direktori...
# 2  https://putusan3.mahkamahagung.go.id/direktori...
# 3  https://putusan3.mahkamahagung.go.id/direktori...
# 4  https://putusan3.mahkamahagung.go.id/direktori...
#
#                                             link_pdf  \
# 0  https://putusan3.mahkamahagung.go.id/direktori...
# 1  https://putusan3.mahkamahagung.go.id/direktori...
# 2  https://putusan3.mahkamahagung.go.id/direktori...
# 3                                                NaN
# 4  https://putusan3.mahkamahagung.go.id/direktori...
#
#                                        file_name_pdf  \
# 0   putusan_621_pid.b_2024_pn_mdn_20250625173548.pdf
# 1  putusan_1157_pid.b_2024_pn_mdn_20250625173554.pdf
# 2  putusan_2065_pid.b_2024_pn_mdn_20250625173613.pdf
# 3                                                NaN
# 4   putusan_338_pid.b_2024_pn_mdn_20250625173625.pdf
#
#                                             text_pdf
# 0  Direktori Putusan Mahkamah Agung Republik Indo...
# 1  Direktori Putusan Mahkamah Agung Republik Indo...
# 2  Direktori Putusan Mahkamah Agung Republik Indo...
# 3                                                NaN
# 4  Direktori Putusan Mahkamah Agung Republik Indo...
#
# [5 rows x 23 columns]

# %%
# Cek nama kolom
df.columns
# Out:
# Index(['judul', 'nomor', 'tingkat_proses', 'klasifikasi', 'kata_kunci',
#        'tahun', 'tanggal_register', 'lembaga_peradilan',
#        'jenis_lembaga_peradilan', 'hakim_ketua', 'hakim_anggota', 'panitera',
#        'amar', 'amar_lainnya', 'catatan_amar', 'tanggal_musyawarah',
#        'tanggal_dibacakan', 'kaidah', 'abstrak', 'link', 'link_pdf',
#        'file_name_pdf', 'text_pdf'],
#       dtype='object')

# %%
# Hapus duplikat
df = df.drop_duplicates()

# %%
# Hapus kolom yang tidak diperlukan
columns_to_drop = ['link', 'link_pdf', 'file_name_pdf', 'text_pdf',]  # sesuaikan jika ada
df = df.drop(columns=columns_to_drop, errors='ignore')

# %%
# Fungsi untuk membersihkan teks
def preprocess_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r'm\s*e\s*n\s*g\s*a\s*d\s*i\s*l\s*i\s*:?', '', text)
    text = re.sub(r'[^a-z0-9\s]', '', text)
    return text.strip()

# Preprocessing pada kolom catatan_amar
df['catatan_amar'] = df['catatan_amar'].apply(preprocess_text)

# %%
# Fungsi ekstraksi pidana penjara
def extract_pidana_penjara(text):
    if pd.isna(text):
        return None

    pattern = r'(?:pidana penjara selama|pidana penjara masing-masing|pidana penjara masing masing|pidana penjara masingmasing)\s+(.*?)(?:\s+menetapkan|\s+memerintahkan|$)'
    match = re.search(pattern, text, re.IGNORECASE | re.DOTALL)

    return match.group(1).strip() if match else None

# Tambahkan kolom hasil ekstraksi pidana penjara
df['pidana_penjara'] = df['catatan_amar'].apply(extract_pidana_penjara)

# Tampilkan hasil akhir
df
# Out:
#                                                  judul  \
# 0    Putusan PN MEDAN Nomor 621/Pid.B/2024/PN Mdn T...
# 1    Putusan PN MEDAN Nomor 1157/Pid.B/2024/PN Mdn ...
# 2    Putusan PN MEDAN Nomor 2065/Pid.B/2024/PN Mdn ...
# 3    Putusan PN MEDAN Nomor 826/Pid.B/2024/PN Mdn T...
# 4    Putusan PN MEDAN Nomor 338/Pid.B/2024/PN Mdn T...
# ..                                                 ...
# 105  Putusan PN MEDAN Nomor 2173/Pid.B/2023/PN Mdn ...
# 106  Putusan PN MEDAN Nomor 2343/Pid.B/2023/PN Mdn ...
# 107  Putusan PA SAROLANGUN Nomor 179/Pdt.G/2025/PA....
# 108  Putusan PA SAROLANGUN Nomor 177/Pdt.G/2025/PA....
# 109  Putusan PA Rumbia Nomor 119/Pdt.G/2025/PA.Rmb ...
#
#                       nomor tingkat_proses  \
# 0     621/Pid.B/2024/PN Mdn        Pertama
# 1    1157/Pid.B/2024/PN Mdn        Pertama
# 2    2065/Pid.B/2024/PN Mdn        Pertama
# 3     826/Pid.B/2024/PN Mdn        Pertama
# 4     338/Pid.B/2024/PN Mdn        Pertama
# ..                      ...            ...
# 105  2173/Pid.B/2023/PN Mdn        Pertama
# 106  2343/Pid.B/2023/PN Mdn        Pertama
# 107   179/Pdt.G/2025/PA.Srl        Pertama
# 108   177/Pdt.G/2025/PA.Srl        Pertama
# 109   119/Pdt.G/2025/PA.Rmb        Pertama
#
#                                     klasifikasi    kata_kunci  tahun  \
# 0      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 1      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 2      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 3      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 4      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# ..                                          ...           ...    ...
# 105    Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 106    Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 107  Perdata Agama \n Perdata Agama  Perceraian   Cerai Gugat   2025
# 108  Perdata Agama \n Perdata Agama  Perceraian   Cerai Talak   2025
# 109  Perdata Agama \n Perdata Agama  Perceraian   Cerai Gugat   2025
#
#      tanggal_register lembaga_peradilan jenis_lembaga_peradilan  \
# 0          2 Mei 2024          PN MEDAN                      PN
# 1        22 Juli 2024          PN MEDAN                      PN
# 2    12 Nopember 2024          PN MEDAN                      PN
# 3         3 Juni 2024          PN MEDAN                      PN
# 4        4 Maret 2024          PN MEDAN                      PN
# ..                ...               ...                     ...
# 105   26 Oktober 2023          PN MEDAN                      PN
# 106  14 Nopember 2023          PN MEDAN                      PN
# 107       26 Mei 2025     PA SAROLANGUN                      PA
# 108       22 Mei 2025     PA SAROLANGUN                      PA
# 109       20 Mei 2025         PA Rumbia                      PA
#
#                               hakim_ketua  \
# 0          Hakim Ketua Lucas Sahabat Duha
# 1           Hakim Ketua Donald Panggabean
# 2              Hakim Ketua Muhammad Kasim
# 3      Hakim Ketua Frans Effendi Manurung
# 4                Hakim Ketua Khairulludin
# ..                                    ...
# 105             Hakim Ketua Fauzul Hamdi.
# 106                Hakim Ketua Eti Astuti
# 107  Hakim Tunggal Taufiqur Rakhman Alhaq
# 108  Hakim Tunggal Taufiqur Rakhman Alhaq
# 109           Hakim Ketua Kamariah Sunusi
#
#                                          hakim_anggota  \
# 0    Mhbr Hakim Anggota  Mohammad Yusafrihardi Girs...
# 1    Br Hakim Anggota  Zufida Hanum, Hakim Anggota ...
# 2    Hakim Anggota  Frans Effendi Manurung, Br Haki...
# 3    Br Hakim Anggota  M. Nazir, Hakim Anggota  Len...
# 4    Mhbr Hakim Anggota  Khamozaro Waruwu, Hakim An...
# ..                                                 ...
# 105  Hakim Anggota  Nelson Panjaitan, Br Hakim Angg...
# 106  Hakim Anggota  Fahren, Br Hakim Anggota  Nurmiati
# 107               Hakim Tunggal Taufiqur Rakhman Alhaq
# 108               Hakim Tunggal Taufiqur Rakhman Alhaq
# 109  Hakim Anggota  Perlita Nathania, Br Hakim Angg...
#
#                                    panitera       amar  \
# 0      Panitera Pengganti: Potalfin Siregar  Lain-lain
# 1         Panitera Pengganti Berry Prima P.  Lain-lain
# 2          Panitera Pengganti: Emmy Siahaan  Lain-lain
# 3    Panitera Pengganti Via Ramalia Tarigan  Lain-lain
# 4               Panitera Pengganti: Aryandi  Lain-lain
# ..                                      ...        ...
# 105             Panitera Pengganti: Aryandi  Lain-lain
# 106        Panitera Pengganti: Ngatas Purba  Lain-lain
# 107               Panitera Pengganti: Arsad  Lain-lain
# 108        Panitera Pengganti: Anita Kirana  Lain-lain
# 109     Panitera Pengganti Syafardin Jumain  Lain-lain
#
#                       amar_lainnya  \
# 0    PIDANA PENJARA WAKTU TERTENTU
# 1    PIDANA PENJARA WAKTU TERTENTU
# 2    PIDANA PENJARA WAKTU TERTENTU
# 3    PIDANA PENJARA WAKTU TERTENTU
# 4    PIDANA PENJARA WAKTU TERTENTU
# ..                             ...
# 105  PIDANA PENJARA WAKTU TERTENTU
# 106  PIDANA PENJARA WAKTU TERTENTU
# 107                     DIKABULKAN
# 108                     DIKABULKAN
# 109                     DIKABULKAN
#
#                                           catatan_amar tanggal_musyawarah  \
# 0    menyatakan terdakwa i m kandi safari dan terda...       23 Juli 2024
# 1    menyatakan terdakwa erwin tersebut diatas terb...     2 Oktober 2024
# 2    menyatakan terdakwa joshua cornelius manik ali...   19 Desember 2024
# 3    1 menyatakan terdakwa i ganda satria simanjunt...       18 Juli 2024
# 4    menyatakan terdakwa m syafrizal alias sahrijal...        13 Mei 2024
# ..                                                 ...                ...
# 105  menyatakan terdakwaarif ramadhan als arif kebo...     9 Januari 2024
# 106  menyatakan terdakwa terdakwa i deni aman gulo ...     4 Januari 2024
# 107  menyatakan tergugat yang telah dipanggil secar...       25 Juni 2025
# 108  1  menyatakan termohon yang telah dipanggil se...       25 Juni 2025
# 109  menyatakan tergugat yang telah dipanggil secar...       25 Juni 2025
#
#     tanggal_dibacakan kaidah  abstrak  \
# 0        23 Juli 2024      —      NaN
# 1      2 Oktober 2024      —      NaN
# 2    19 Desember 2024      —      NaN
# 3        18 Juli 2024      —      NaN
# 4         13 Mei 2024      —      NaN
# ..                ...    ...      ...
# 105    9 Januari 2024      —      NaN
# 106    4 Januari 2024      —      NaN
# 107      25 Juni 2025      —      NaN
# 108      25 Juni 2025      —      NaN
# 109      25 Juni 2025      —      NaN
#
#                                         pidana_penjara
# 0                                                 None
# 1                                          2 dua tahun
# 2                                         1 satu tahun
# 3              1 satu tahun dan 6 enam bulan penjara 3
# 4                        1 satu tahun dan 6 enam bulan
# ..                                                 ...
# 105                      1 satu tahun dan 6 enam bulan
# 106  selama terdakwa i deni aman gulo als denis gul...
# 107                                               None
# 108                                               None
# 109                                               None
#
# [107 rows x 20 columns]

# %%
# Fungsi ekstraksi keadaan terdakwa
def extract_keadaan(text):
    if pd.isna(text):
        return None

    pattern = r'(?:meyakinkan bersalah|meyakinkanbersalah|menyatakan bersalah|dinyatakan bersalah|meyakinkan terbukti bersalah)\s+(.*?)(?:\s+menjatuhkan pidana|$)'
    match = re.search(pattern, text, re.IGNORECASE | re.DOTALL)

    return match.group(1).strip() if match else None

# Tambahkan kolom hasil ekstraksi keadaan
df['kategori_penganiayaan'] = df['catatan_amar'].apply(extract_keadaan)

# Tampilkan hasil akhir
df
# Out:
#                                                  judul  \
# 0    Putusan PN MEDAN Nomor 621/Pid.B/2024/PN Mdn T...
# 1    Putusan PN MEDAN Nomor 1157/Pid.B/2024/PN Mdn ...
# 2    Putusan PN MEDAN Nomor 2065/Pid.B/2024/PN Mdn ...
# 3    Putusan PN MEDAN Nomor 826/Pid.B/2024/PN Mdn T...
# 4    Putusan PN MEDAN Nomor 338/Pid.B/2024/PN Mdn T...
# ..                                                 ...
# 105  Putusan PN MEDAN Nomor 2173/Pid.B/2023/PN Mdn ...
# 106  Putusan PN MEDAN Nomor 2343/Pid.B/2023/PN Mdn ...
# 107  Putusan PA SAROLANGUN Nomor 179/Pdt.G/2025/PA....
# 108  Putusan PA SAROLANGUN Nomor 177/Pdt.G/2025/PA....
# 109  Putusan PA Rumbia Nomor 119/Pdt.G/2025/PA.Rmb ...
#
#                       nomor tingkat_proses  \
# 0     621/Pid.B/2024/PN Mdn        Pertama
# 1    1157/Pid.B/2024/PN Mdn        Pertama
# 2    2065/Pid.B/2024/PN Mdn        Pertama
# 3     826/Pid.B/2024/PN Mdn        Pertama
# 4     338/Pid.B/2024/PN Mdn        Pertama
# ..                      ...            ...
# 105  2173/Pid.B/2023/PN Mdn        Pertama
# 106  2343/Pid.B/2023/PN Mdn        Pertama
# 107   179/Pdt.G/2025/PA.Srl        Pertama
# 108   177/Pdt.G/2025/PA.Srl        Pertama
# 109   119/Pdt.G/2025/PA.Rmb        Pertama
#
#                                     klasifikasi    kata_kunci  tahun  \
# 0      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 1      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 2      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 3      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 4      Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# ..                                          ...           ...    ...
# 105    Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 106    Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan   2024
# 107  Perdata Agama \n Perdata Agama  Perceraian   Cerai Gugat   2025
# 108  Perdata Agama \n Perdata Agama  Perceraian   Cerai Talak   2025
# 109  Perdata Agama \n Perdata Agama  Perceraian   Cerai Gugat   2025
#
#      tanggal_register lembaga_peradilan jenis_lembaga_peradilan  \
# 0          2 Mei 2024          PN MEDAN                      PN
# 1        22 Juli 2024          PN MEDAN                      PN
# 2    12 Nopember 2024          PN MEDAN                      PN
# 3         3 Juni 2024          PN MEDAN                      PN
# 4        4 Maret 2024          PN MEDAN                      PN
# ..                ...               ...                     ...
# 105   26 Oktober 2023          PN MEDAN                      PN
# 106  14 Nopember 2023          PN MEDAN                      PN
# 107       26 Mei 2025     PA SAROLANGUN                      PA
# 108       22 Mei 2025     PA SAROLANGUN                      PA
# 109       20 Mei 2025         PA Rumbia                      PA
#
#                               hakim_ketua  ...  \
# 0          Hakim Ketua Lucas Sahabat Duha  ...
# 1           Hakim Ketua Donald Panggabean  ...
# 2              Hakim Ketua Muhammad Kasim  ...
# 3      Hakim Ketua Frans Effendi Manurung  ...
# 4                Hakim Ketua Khairulludin  ...
# ..                                    ...  ...
# 105             Hakim Ketua Fauzul Hamdi.  ...
# 106                Hakim Ketua Eti Astuti  ...
# 107  Hakim Tunggal Taufiqur Rakhman Alhaq  ...
# 108  Hakim Tunggal Taufiqur Rakhman Alhaq  ...
# 109           Hakim Ketua Kamariah Sunusi  ...
#
#                                    panitera       amar  \
# 0      Panitera Pengganti: Potalfin Siregar  Lain-lain
# 1         Panitera Pengganti Berry Prima P.  Lain-lain
# 2          Panitera Pengganti: Emmy Siahaan  Lain-lain
# 3    Panitera Pengganti Via Ramalia Tarigan  Lain-lain
# 4               Panitera Pengganti: Aryandi  Lain-lain
# ..                                      ...        ...
# 105             Panitera Pengganti: Aryandi  Lain-lain
# 106        Panitera Pengganti: Ngatas Purba  Lain-lain
# 107               Panitera Pengganti: Arsad  Lain-lain
# 108        Panitera Pengganti: Anita Kirana  Lain-lain
# 109     Panitera Pengganti Syafardin Jumain  Lain-lain
#
#                       amar_lainnya  \
# 0    PIDANA PENJARA WAKTU TERTENTU
# 1    PIDANA PENJARA WAKTU TERTENTU
# 2    PIDANA PENJARA WAKTU TERTENTU
# 3    PIDANA PENJARA WAKTU TERTENTU
# 4    PIDANA PENJARA WAKTU TERTENTU
# ..                             ...
# 105  PIDANA PENJARA WAKTU TERTENTU
# 106  PIDANA PENJARA WAKTU TERTENTU
# 107                     DIKABULKAN
# 108                     DIKABULKAN
# 109                     DIKABULKAN
#
#                                           catatan_amar tanggal_musyawarah  \
# 0    menyatakan terdakwa i m kandi safari dan terda...       23 Juli 2024
# 1    menyatakan terdakwa erwin tersebut diatas terb...     2 Oktober 2024
# 2    menyatakan terdakwa joshua cornelius manik ali...   19 Desember 2024
# 3    1 menyatakan terdakwa i ganda satria simanjunt...       18 Juli 2024
# 4    menyatakan terdakwa m syafrizal alias sahrijal...        13 Mei 2024
# ..                                                 ...                ...
# 105  menyatakan terdakwaarif ramadhan als arif kebo...     9 Januari 2024
# 106  menyatakan terdakwa terdakwa i deni aman gulo ...     4 Januari 2024
# 107  menyatakan tergugat yang telah dipanggil secar...       25 Juni 2025
# 108  1  menyatakan termohon yang telah dipanggil se...       25 Juni 2025
# 109  menyatakan tergugat yang telah dipanggil secar...       25 Juni 2025
#
#     tanggal_dibacakan kaidah abstrak  \
# 0        23 Juli 2024      —     NaN
# 1      2 Oktober 2024      —     NaN
# 2    19 Desember 2024      —     NaN
# 3        18 Juli 2024      —     NaN
# 4         13 Mei 2024      —     NaN
# ..                ...    ...     ...
# 105    9 Januari 2024      —     NaN
# 106    4 Januari 2024      —     NaN
# 107      25 Juni 2025      —     NaN
# 108      25 Juni 2025      —     NaN
# 109      25 Juni 2025      —     NaN
#
#                                         pidana_penjara  \
# 0                                                 None
# 1                                          2 dua tahun
# 2                                         1 satu tahun
# 3              1 satu tahun dan 6 enam bulan penjara 3
# 4                        1 satu tahun dan 6 enam bulan
# ..                                                 ...
# 105                      1 satu tahun dan 6 enam bulan
# 106  selama terdakwa i deni aman gulo als denis gul...
# 107                                               None
# 108                                               None
# 109                                               None
#
#                                  kategori_penganiayaan
# 0    melakukan tindak pidana dengan terangterangan ...
# 1    melakukan tindak pidana secara bersamasama mel...
# 2    melakukan tindak pidana penganiayaan sebagaima...
# 3    melakukan tindak pidana kekerasan terhadap ora...
# 4    melakukan tindak pidana dengan terang terangan...
# ..                                                 ...
# 105  melakukan tindak pidanapenganiayaansebagaimana...
# 106  melakukan tindak pidana pengeroyokan sebagaima...
# 107                                               None
# 108                                               None
# 109                                               None
#
# [107 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['judul', 'nomor', 'tingkat_proses', 'klasifikasi', 'kata_kunci',
#        'tahun', 'tanggal_register', 'lembaga_peradilan',
#        'jenis_lembaga_peradilan', 'hakim_ketua', 'hakim_anggota', 'panitera',
#        'amar', 'amar_lainnya', 'catatan_amar', 'tanggal_musyawarah',
#        'tanggal_dibacakan', 'kaidah', 'abstrak', 'pidana_penjara',
#        'kategori_penganiayaan'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 0 to 109
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   judul                    107 non-null    object
#  1   nomor                    107 non-null    object
#  2   tingkat_proses           107 non-null    object
#  3   klasifikasi              107 non-null    object
#  4   kata_kunci               107 non-null    object
#  5   tahun                    107 non-null    int64
#  6   tanggal_register         107 non-null    object
#  7   lembaga_peradilan        107 non-null    object
#  8   jenis_lembaga_peradilan  107 non-null    object
#  9   hakim_ketua              107 non-null    object
#  10  hakim_anggota            107 non-null    object
#  11  panitera                 107 non-null    object
#  12  amar                     107 non-null    object
#  13  amar_lainnya             107 non-null    object
#  14  catatan_amar             107 non-null    object
#  15  tanggal_musyawarah       107 non-null    object
#  16  tanggal_dibacakan        107 non-null    object
#  17  kaidah                   107 non-null    object
#  18  abstrak                  0 non-null      float64
#  19  pidana_penjara           97 non-null     object
#  20  kategori_penganiayaan    95 non-null     object
# dtypes: float64(1), int64(1), object(19)
# memory usage: 18.4+ KB

# %%
# Cek jumlah missing value per kolom ===
print(df.isnull().sum())
# Out:
# judul                        0
# nomor                        0
# tingkat_proses               0
# klasifikasi                  0
# kata_kunci                   0
# tahun                        0
# tanggal_register             0
# lembaga_peradilan            0
# jenis_lembaga_peradilan      0
# hakim_ketua                  0
# hakim_anggota                0
# panitera                     0
# amar                         0
# amar_lainnya                 0
# catatan_amar                 0
# tanggal_musyawarah           0
# tanggal_dibacakan            0
# kaidah                       0
# abstrak                    107
# pidana_penjara              10
# kategori_penganiayaan       12
# dtype: int64

# %%
columns_to_drop = [
    'abstrak','kaidah'
]
df = df.drop(columns=columns_to_drop)

# %%
print(df.isnull().sum())
# Out:
# judul                       0
# nomor                       0
# tingkat_proses              0
# klasifikasi                 0
# kata_kunci                  0
# tahun                       0
# tanggal_register            0
# lembaga_peradilan           0
# jenis_lembaga_peradilan     0
# hakim_ketua                 0
# hakim_anggota               0
# panitera                    0
# amar                        0
# amar_lainnya                0
# catatan_amar                0
# tanggal_musyawarah          0
# tanggal_dibacakan           0
# pidana_penjara             10
# kategori_penganiayaan      12
# dtype: int64

# %%
kolom_missing = ['pidana_penjara', 'kategori_penganiayaan']

# %%
df = df.dropna(subset=kolom_missing)

# %%
print(df.isnull().sum())
# Out:
# judul                      0
# nomor                      0
# tingkat_proses             0
# klasifikasi                0
# kata_kunci                 0
# tahun                      0
# tanggal_register           0
# lembaga_peradilan          0
# jenis_lembaga_peradilan    0
# hakim_ketua                0
# hakim_anggota              0
# panitera                   0
# amar                       0
# amar_lainnya               0
# catatan_amar               0
# tanggal_musyawarah         0
# tanggal_dibacakan          0
# pidana_penjara             0
# kategori_penganiayaan      0
# dtype: int64

# %%
df.head(10)
# Out:
#                                                 judul                   nomor  \
# 1   Putusan PN MEDAN Nomor 1157/Pid.B/2024/PN Mdn ...  1157/Pid.B/2024/PN Mdn
# 2   Putusan PN MEDAN Nomor 2065/Pid.B/2024/PN Mdn ...  2065/Pid.B/2024/PN Mdn
# 3   Putusan PN MEDAN Nomor 826/Pid.B/2024/PN Mdn T...   826/Pid.B/2024/PN Mdn
# 4   Putusan PN MEDAN Nomor 338/Pid.B/2024/PN Mdn T...   338/Pid.B/2024/PN Mdn
# 5   Putusan PN MEDAN Nomor 1116/Pid.B/2024/PN Mdn ...  1116/Pid.B/2024/PN Mdn
# 6   Putusan PN MEDAN Nomor 598/Pid.B/2024/PN Mdn T...   598/Pid.B/2024/PN Mdn
# 7   Putusan PN MEDAN Nomor 1904/Pid.B/2024/PN Mdn ...  1904/Pid.B/2024/PN Mdn
# 8   Putusan PN MEDAN Nomor 255/Pid.B/2024/PN Mdn T...   255/Pid.B/2024/PN Mdn
# 9   Putusan PN MEDAN Nomor 597/Pid.B/2024/PN Mdn T...   597/Pid.B/2024/PN Mdn
# 10  Putusan PN MEDAN Nomor 1115/Pid.B/2024/PN Mdn ...  1115/Pid.B/2024/PN Mdn
#
#    tingkat_proses                               klasifikasi    kata_kunci  \
# 1         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 2         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 3         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 4         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 5         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 6         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 7         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 8         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 9         Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
# 10        Pertama  Pidana Umum \n Pidana Umum  Penganiayaan  Penganiayaan
#
#     tahun  tanggal_register lembaga_peradilan jenis_lembaga_peradilan  \
# 1    2024      22 Juli 2024          PN MEDAN                      PN
# 2    2024  12 Nopember 2024          PN MEDAN                      PN
# 3    2024       3 Juni 2024          PN MEDAN                      PN
# 4    2024      4 Maret 2024          PN MEDAN                      PN
# 5    2024      16 Juli 2024          PN MEDAN                      PN
# 6    2024     30 April 2024          PN MEDAN                      PN
# 7    2024   23 Oktober 2024          PN MEDAN                      PN
# 8    2024  19 Februari 2024          PN MEDAN                      PN
# 9    2024     30 April 2024          PN MEDAN                      PN
# 10   2024      16 Juli 2024          PN MEDAN                      PN
#
#                            hakim_ketua  \
# 1        Hakim Ketua Donald Panggabean
# 2           Hakim Ketua Muhammad Kasim
# 3   Hakim Ketua Frans Effendi Manurung
# 4             Hakim Ketua Khairulludin
# 5            Hakim Ketua Sarma Siregar
# 6             Hakim Ketua Khairulludin
# 7            Hakim Ketua Sarma Siregar
# 8        Hakim Ketua Firza Andriansyah
# 9     Hakim Ketua Efrata Happy Tarigan
# 10           Hakim Ketua Sarma Siregar
#
#                                         hakim_anggota  \
# 1   Br Hakim Anggota  Zufida Hanum, Hakim Anggota ...
# 2   Hakim Anggota  Frans Effendi Manurung, Br Haki...
# 3   Br Hakim Anggota  M. Nazir, Hakim Anggota  Len...
# 4   Mhbr Hakim Anggota  Khamozaro Waruwu, Hakim An...
# 5   Hakim Anggota  Vera Yetti Magdalena, Br Hakim ...
# 6   Mhbr Hakim Anggota  Khamozaro Waruwu, Hakim An...
# 7   Br Hakim Anggota  Muhammad Kasim, Hakim Anggot...
# 8   Br Hakim Anggota  Martua Sagala, Hakim Anggota...
# 9   Hakim Anggota  Evelyne Napitupulu, M.hbr Hakim...
# 10  Hakim Anggota  Vera Yetti Magdalena, Br Hakim ...
#
#                                         panitera       amar  \
# 1              Panitera Pengganti Berry Prima P.  Lain-lain
# 2               Panitera Pengganti: Emmy Siahaan  Lain-lain
# 3         Panitera Pengganti Via Ramalia Tarigan  Lain-lain
# 4                    Panitera Pengganti: Aryandi  Lain-lain
# 5               Panitera Pengganti: Emmy Siahaan  Lain-lain
# 6       Panitera Pengganti Abdul Rahman Rangkuti  Lain-lain
# 7               Panitera Pengganti: Emmy Siahaan  Lain-lain
# 8   S.kom, Panitera Pengganti Rahmadan Syahputra  Lain-lain
# 9                    Panitera Pengganti Romadona  Lain-lain
# 10        Panitera Pengganti: Nahwan Z. Nasution  Lain-lain
#
#                      amar_lainnya  \
# 1   PIDANA PENJARA WAKTU TERTENTU
# 2   PIDANA PENJARA WAKTU TERTENTU
# 3   PIDANA PENJARA WAKTU TERTENTU
# 4   PIDANA PENJARA WAKTU TERTENTU
# 5   PIDANA PENJARA WAKTU TERTENTU
# 6   PIDANA PENJARA WAKTU TERTENTU
# 7   PIDANA PENJARA WAKTU TERTENTU
# 8   PIDANA PENJARA WAKTU TERTENTU
# 9   PIDANA PENJARA WAKTU TERTENTU
# 10  PIDANA PENJARA WAKTU TERTENTU
#
#                                          catatan_amar tanggal_musyawarah  \
# 1   menyatakan terdakwa erwin tersebut diatas terb...     2 Oktober 2024
# 2   menyatakan terdakwa joshua cornelius manik ali...   19 Desember 2024
# 3   1 menyatakan terdakwa i ganda satria simanjunt...       18 Juli 2024
# 4   menyatakan terdakwa m syafrizal alias sahrijal...        13 Mei 2024
# 5   menyatakan terdakwa puja asmara alias puja ter...     1 Oktober 2024
# 6   1 menyatakan terdakwa budi irawan barus terseb...       17 Juli 2024
# 7   menyatakan terdakwa misael s simanjuntak terse...   17 Desember 2024
# 8   menyatakan terdakwa abdul saman tersebut diata...         7 Mei 2024
# 9   menyatakan terdakwa yosua gerald g hasugian al...       15 Juli 2024
# 10  menyatakan terdakwa tarmizi alias tiar tersebu...     1 Oktober 2024
#
#    tanggal_dibacakan                           pidana_penjara  \
# 1     2 Oktober 2024                              2 dua tahun
# 2   19 Desember 2024                             1 satu tahun
# 3       18 Juli 2024  1 satu tahun dan 6 enam bulan penjara 3
# 4        13 Mei 2024            1 satu tahun dan 6 enam bulan
# 5     1 Oktober 2024                            7 tujuh bulan
# 6       17 Juli 2024       2 dua tahun dan 10 sepuluh bulan 3
# 7   17 Desember 2024                              1satu tahun
# 8         7 Mei 2024                  selama 10 sepuluh bulan
# 9       15 Juli 2024            1 satu tahun dan 3 tiga bulan
# 10    1 Oktober 2024                            7 tujuh bulan
#
#                                 kategori_penganiayaan
# 1   melakukan tindak pidana secara bersamasama mel...
# 2   melakukan tindak pidana penganiayaan sebagaima...
# 3   melakukan tindak pidana kekerasan terhadap ora...
# 4   melakukan tindak pidana dengan terang terangan...
# 5   melakukan tindak pidana turut serta melakukan ...
# 6   melakukan tindak pidana dimuka umum secara ber...
# 7   melakukan tindak pidana penganiayaan yang meng...
# 8   melakukan tindak pidana melakukan kekerasan te...
# 9   melakukan tindak pidana penganiayaan sebagaima...
# 10  melakukan tindak pidana turut serta melakukan ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 1 to 106
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   judul                    90 non-null     object
#  1   nomor                    90 non-null     object
#  2   tingkat_proses           90 non-null     object
#  3   klasifikasi              90 non-null     object
#  4   kata_kunci               90 non-null     object
#  5   tahun                    90 non-null     int64
#  6   tanggal_register         90 non-null     object
#  7   lembaga_peradilan        90 non-null     object
#  8   jenis_lembaga_peradilan  90 non-null     object
#  9   hakim_ketua              90 non-null     object
#  10  hakim_anggota            90 non-null     object
#  11  panitera                 90 non-null     object
#  12  amar                     90 non-null     object
#  13  amar_lainnya             90 non-null     object
#  14  catatan_amar             90 non-null     object
#  15  tanggal_musyawarah       90 non-null     object
#  16  tanggal_dibacakan        90 non-null     object
#  17  pidana_penjara           90 non-null     object
#  18  kategori_penganiayaan    90 non-null     object
# dtypes: int64(1), object(18)
# memory usage: 14.1+ KB

# %%
# Simpan hasil ke file CSV di local folder
output_path = 'data/preprocessed/cleaned_putusan_hasil.csv'
df.to_csv(output_path, index=False)

print(f"File berhasil disimpan di {output_path}")
# Out:
# File berhasil disimpan di data/preprocessed/cleaned_putusan_hasil.csv
